# %%
from agent_core import IntelligenceAgent
from utils import log_event

session = get_active_session()

agent = IntelligenceAgent(session)

query = "Why did revenue drop last week and did any policies get violated?"
result = agent.run(query)

print(result["final_answer"])
